# %%
a = "Python"
b = a

a = "SQL"

print(a)
print(b)

# %%
x = [10,20]

y = x

x.append(30)

print(x)

print(y)

# %%
print(10 > 5)

# %%
a = 10

b = 10

print(a == b)

# %%
a = [1,2]

b = [1,2]

print(a == b)

# %%
a = [1,2]

b = [1,2]

print(a is b)

# %%
a = [10, 20]
b = [10, 20]
c = a

print(a == b)
print(a is b)
print(a == c)
print(a is c)

# %%
arr = [1, 2, 3, 1, 2]

result = 0

for num in arr:
    result ^= num

print(result)
# Out:
# 3

# %%
"th" in "Python"
# Out:
# True

# %%
name = "onkar"

print(name.upper())
# Out:
# ONKAR
# python

# %%
print("PYTHON".lower())
# Out:
# python

# %%
text = "   Python   "

print(text.strip())
# Out:
# Python

# %%
text = "I love Java"

print(text.replace("Java","Python"))
# Out:
# I love Python

# %%
text = "SQL Python Azure"

print(text.split())
# Out:
# ['SQL', 'Python', 'Azure']

# %%
skills = ["SQL","Python","Azure"]

print("-".join(skills))
print(" ".join(skills))
# Out:
# SQL-Python-Azure
# SQL Python Azure

# %%
text = "Python"

print(text.find("t"))
# Out:
# 2

# %%
text = "banana"

print(text.count("a"))
# Out:
# 3

# %%
text = "Python"

print(text[2])
# Out:
# t

# %%
text = "Python"

print(text[-3])
# Out:
# h

# %%
text = "Python"

print(text[1:5])
# Out:
# ytho

# %%
text = "Python"

print(text[::-1])
